# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset=pd.read_excel("Superstore_USA.xlsx")

# %% [markdown]
# #About ORDER PRIORITY

# %%
dataset.loc[:, 'Product Base Margin'] = dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean())
dataset['Order Priority']= dataset.loc[:, 'Order Priority'].replace('Critical ','Critical')
print(dataset['Order Priority'].value_counts())
plt.figure(figsize=(5,4))
sns.countplot(x='Order Priority',data=dataset)
plt.title('Count of Order Priority')
plt.figure(figsize=(4,3))
plt.show()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %% [markdown]
# #About SHIP MODE

# %%
print(dataset["Ship Mode"].value_counts())
x= dataset["Ship Mode"].value_counts().index
y= dataset["Ship Mode"].value_counts().values
plt.pie(y,labels=x,autopct='%0.2f%%')
plt.legend(loc=1)
plt.show()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %% [markdown]
# #Bivariate Analysis

# %%
sns.countplot(x='Ship Mode', data=dataset,hue='Product Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #Cutomer Segment

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Customer Segment', data=dataset)
plt.title('Count of Customer Segment')
plt.show()
#in this we get to know that we have more customers from Corporate and less customer from Consumer(Students)

# %% [markdown]
# #Product Category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Product Category', data=dataset)
plt.title('Count of Product Category')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Product Category', data=dataset,hue="Product Sub-Category")
plt.title('Count of Product Category')
plt.show()
